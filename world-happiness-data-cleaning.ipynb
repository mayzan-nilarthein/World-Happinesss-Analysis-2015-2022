# %% [markdown]
# # World Happiness Analysis 2015 to 2021

# %%
import pandas as pd
import numpy as np

# %%
df2015 = pd.read_csv('Data/World Happiness Report 2015-2021/2015.csv')

# %%
df2016 = pd.read_csv('Data/World Happiness Report 2015-2021/2016.csv')

# %%
df2017 = pd.read_csv('Data/World Happiness Report 2015-2021/2017.csv')

# %%
df2018 = pd.read_csv('Data/World Happiness Report 2015-2021/2018.csv')

# %%
df2019 = pd.read_csv('Data/World Happiness Report 2015-2021/2019.csv')

# %%
df2020 = pd.read_csv('Data/World Happiness Report 2015-2021/2020.csv')

# %%
df2021 = pd.read_csv('Data/World Happiness Report 2015-2021/2021.csv')

# %% [markdown]
# ##### Add 'Year' Column in each dataset

# %%
df2015['Year'] = '2015'
df2016['Year'] = '2016'
df2017['Year'] = '2017'
df2018['Year'] = '2018'
df2019['Year'] = '2019'
df2020['Year'] = '2020'
df2021['Year'] = '2021'

# %% [markdown]
# ###### Adjust column names

# %%
df2015.shape, df2016.shape, df2017.shape, df2018.shape, df2019.shape, df2020.shape, df2021.shape
# Out:
# ((158, 13), (157, 14), (155, 13), (156, 10), (156, 10), (153, 21), (149, 21))

# %% [markdown]
# ## Df2015

# %%
df2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df2015.shape  , df2015.columns.to_list()
# Out:
# ((158, 13),
#  ['Country',
#   'Region',
#   'Happiness Rank',
#   'Happiness Score',
#   'Standard Error',
#   'Economy (GDP per Capita)',
#   'Family',
#   'Health (Life Expectancy)',
#   'Freedom',
#   'Trust (Government Corruption)',
#   'Generosity',
#   'Dystopia Residual',
#   'Year'])

# %% [markdown]
# ## Df2016

# %%
df2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df2016.shape  ,df2016.columns.to_list()
# Out:
# ((157, 14),
#  ['Country',
#   'Region',
#   'Happiness Rank',
#   'Happiness Score',
#   'Lower Confidence Interval',
#   'Upper Confidence Interval',
#   'Economy (GDP per Capita)',
#   'Family',
#   'Health (Life Expectancy)',
#   'Freedom',
#   'Trust (Government Corruption)',
#   'Generosity',
#   'Dystopia Residual',
#   'Year'])

# %% [markdown]
# ## Df2017

# %%
df2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual  Year
# ...

# %%
df2017.shape  , df2017.columns.to_list()
# Out:
# ((155, 13),
#  ['Country',
#   'Happiness.Rank',
#   'Happiness.Score',
#   'Whisker.high',
#   'Whisker.low',
#   'Economy..GDP.per.Capita.',
#   'Family',
#   'Health..Life.Expectancy.',
#   'Freedom',
#   'Generosity',
#   'Trust..Government.Corruption.',
#   'Dystopia.Residual',
#   'Year'])

# %%
#rename some column names
df2017= df2017.rename(columns={'Happiness.Rank':'Happiness Rank','Happiness.Score':'Happiness Score','Economy..GDP.per.Capita.':'Economy (GDP per Capita)', 'Health..Life.Expectancy.':'Health (Life Expectancy)','Trust..Government.Corruption.':'Trust (Government Corruption)','Dystopia.Residual':'Dystopia Residual'})

# %%
df2017 = df2017.merge(df2015[["Country","Region"]], on="Country", how="left")
df2017["Region"] = df2017["Region"].fillna('-')

# %%
df2017.columns.to_list()
# Out:
# ['Country',
#  'Happiness Rank',
#  'Happiness Score',
#  'Whisker.high',
#  'Whisker.low',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Generosity',
#  'Trust (Government Corruption)',
#  'Dystopia Residual',
#  'Year',
#  'Region']

# %% [markdown]
# ## Df2018

# %%
df2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption  Year
# 0                      0.393  2018
# 1                      0.340  2018
# ...

# %%
df2018.shape  , df2018.columns.to_list()
# Out:
# ((156, 10),
#  ['Overall rank',
#   'Country or region',
#   'Score',
#   'GDP per capita',
#   'Social support',
#   'Healthy life expectancy',
#   'Freedom to make life choices',
#   'Generosity',
#   'Perceptions of corruption',
#   'Year'])

# %%
#rename some column names
df2018 = df2018.rename(columns={'Overall rank':'Happiness Rank','Country or region':'Country','Score':'Happiness Score','GDP per capita':'Economy (GDP per Capita)','Social support':'Family','Healthy life expectancy':'Health (Life Expectancy)','Freedom to make life choices':'Freedom','Perceptions of corruption':'Trust (Government Corruption)'})

# %%
df2018 = df2018.merge(df2015[["Country","Region"]], on="Country", how="left")
df2018["Region"] = df2018["Region"].fillna('-')

# %%
df2018.columns.to_list()
# Out:
# ['Happiness Rank',
#  'Country',
#  'Happiness Score',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Generosity',
#  'Trust (Government Corruption)',
#  'Year',
#  'Region']

# %%
df2018['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 36
# Central and Eastern Europe         29
# Western Europe                     20
# Latin America and Caribbean        20
# Middle East and Northern Africa    19
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# -                                   6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %% [markdown]
# ## Df2019

# %%
df2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption  Year
# 0                      0.393  2019
# 1                      0.410  2019
# ...

# %%
df2019.shape  , df2019.columns.to_list()
# Out:
# ((156, 10),
#  ['Overall rank',
#   'Country or region',
#   'Score',
#   'GDP per capita',
#   'Social support',
#   'Healthy life expectancy',
#   'Freedom to make life choices',
#   'Generosity',
#   'Perceptions of corruption',
#   'Year'])

# %%
#rename some column names
df2019 = df2019.rename(columns={'Overall rank':'Happiness Rank','Country or region':'Country','Score':'Happiness Score','GDP per capita':'Economy (GDP per Capita)','Social support':'Family','Healthy life expectancy':'Health (Life Expectancy)','Freedom to make life choices':'Freedom','Perceptions of corruption':'Trust (Government Corruption)'})

# %%
#ref : https://stackoverflow.com/questions/62133801/copy-a-column-value-from-another-dataframe-based-on-a-condition
df2019 = df2019.merge(df2015[["Country","Region"]], on="Country", how="left")
df2019["Region"] = df2019["Region"].fillna('-')

# %%
df2015['Region'].nunique()
# Out:
# 10

# %%
df2019['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 36
# Central and Eastern Europe         28
# Western Europe                     20
# Latin America and Caribbean        20
# Middle East and Northern Africa    19
# Southeastern Asia                   9
# -                                   7
# Southern Asia                       7
# Eastern Asia                        6
# Australia and New Zealand           2
# North America                       2
# Name: Region, dtype: int64

# %%
df2019.head()
# Out:
#    Happiness Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0               1      Finland            7.769                     1.340
# 1               2      Denmark            7.600                     1.383
# 2               3       Norway            7.554                     1.488
# 3               4      Iceland            7.494                     1.380
# 4               5  Netherlands            7.488                     1.396
#
#    Family  Health (Life Expectancy)  Freedom  Generosity  \
# 0   1.587                     0.986    0.596       0.153
# 1   1.573                     0.996    0.592       0.252
# 2   1.582                     1.028    0.603       0.271
# 3   1.624                     1.026    0.591       0.354
# 4   1.522                     0.999    0.557       0.322
#
#    Trust (Government Corruption)  Year          Region
# 0                          0.393  2019  Western Europe
# 1                          0.410  2019  Western Europe
# ...

# %% [markdown]
# ## Df2020

# %%
df2020_copy.columns.to_list()
# Out:
# ['Happiness Rank',
#  'Region',
#  'Freedom',
#  'Happiness Score',
#  'Country',
#  'Generosity',
#  'Generosity',
#  'Family',
#  'Trust (Government Corruption)',
#  'Health (Life Expectancy)',
#  'Economy (GDP per Capita)',
#  'Year']

# %%
df2020_copy = df2020[common_cols].copy()

# %%
#testing
# df2020_copy = df2020_copy.columns.duplicated(keep='last')
df2020_copy = df2020_copy.loc[:,~df2020_copy.columns.duplicated(keep='last')]

# %%
df2020_copy.head()
# Out:
#    Happiness Rank          Region   Freedom  Happiness Score      Country  \
# 0               1  Western Europe  0.662317           7.8087      Finland
# 1               2  Western Europe  0.665040           7.6456      Denmark
# 2               3  Western Europe  0.628954           7.5599  Switzerland
# 3               4  Western Europe  0.661981           7.5045      Iceland
# 4               5  Western Europe  0.670201           7.4880       Norway
#
#    Generosity    Family  Trust (Government Corruption)  \
# 0    0.159670  1.499526                       0.477857
# 1    0.242793  1.503449                       0.495260
# 2    0.269056  1.472403                       0.407946
# 3    0.362330  1.547567                       0.144541
# 4    0.287985  1.495173                       0.434101
#
#    Health (Life Expectancy)  Economy (GDP per Capita)  Year
# 0                  0.961271                  1.285190  2020
# 1                  0.979333                  1.326949  2020
# ...

# %%
df2020 = df2020.loc[:,~df2020.columns.duplicated(keep='last')]

# %%
df2020.head(2)
# Out:
#    Country          Region  Happiness Score  Standard error of ladder score  \
# 0  Finland  Western Europe           7.8087                        0.031156
# 1  Denmark  Western Europe           7.6456                        0.033492
#
#    upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# 0      7.869766      7.747634              10.639267        0.954330
# 1      7.711245      7.579955              10.774001        0.955991
#
#    Healthy life expectancy  Freedom to make life choices  ...  \
# 0                71.900825                      0.949172  ...
# 1                72.402504                      0.951444  ...
#
#    Ladder score in Dystopia  Economy (GDP per Capita)    Family  \
# 0                  1.972317                  1.285190  1.499526
# 1                  1.972317                  1.326949  1.503449
#
#    Health (Life Expectancy)   Freedom  Generosity  \
# 0                  0.961271  0.662317    0.159670
# ...

# %%
df2020_copy.columns.to_list()
# Out:
# ['Happiness Rank',
#  'Region',
#  'Freedom',
#  'Happiness Score',
#  'Country',
#  'Generosity',
#  'Generosity',
#  'Family',
#  'Trust (Government Corruption)',
#  'Health (Life Expectancy)',
#  'Economy (GDP per Capita)',
#  'Year']

# %%
df2020.shape  , df2020.columns.to_list()
# Out:
# ((153, 22),
#  ['Country',
#   'Region',
#   'Happiness Score',
#   'Standard error of ladder score',
#   'upperwhisker',
#   'lowerwhisker',
#   'Logged GDP per capita',
#   'Social support',
#   'Healthy life expectancy',
#   'Freedom to make life choices',
#   'Generosity',
#   'Perceptions of corruption',
#   'Ladder score in Dystopia',
#   'Economy (GDP per Capita)',
#   'Family',
#   'Health (Life Expectancy)',
#   'Freedom',
#   'Generosity',
#   'Trust (Government Corruption)',
#   'Dystopia Residual',
#   'Year',
#   'Happiness Rank'])

# %%
#rename some column names
df2020 = df2020.rename(columns={'Country name':'Country','Regional indicator': 'Region','Ladder score':'Happiness Score','Explained by: Social support':'Family','Explained by: Healthy life expectancy':'Health (Life Expectancy)','Explained by: Freedom to make life choices':'Freedom','Explained by: Perceptions of corruption':'Trust (Government Corruption)','Explained by: Log GDP per capita':'Economy (GDP per Capita)','Explained by: Generosity':'Generosity','Dystopia + residual':'Dystopia Residual'})

# %%
#testing
print([i for i in range(1,10)])
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
df2020['Happiness Rank'] = [i for i in range(1, len(df2020.index)+1)]

# %%
df2020.tail()
# Out:
#                       Country              Region  Happiness Score  \
# 148  Central African Republic  Sub-Saharan Africa           3.4759
# 149                    Rwanda  Sub-Saharan Africa           3.3123
# 150                  Zimbabwe  Sub-Saharan Africa           3.2992
# 151               South Sudan  Sub-Saharan Africa           2.8166
# 152               Afghanistan          South Asia           2.5669
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 148                        0.115183      3.701658      3.250141
# 149                        0.052425      3.415053      3.209547
# 150                        0.058674      3.414202      3.184198
# 151                        0.107610      3.027516      2.605684
# 152                        0.031311      2.628270      2.505530
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 148               6.625160        0.319460                45.200001
# ...

# %%
df2020.columns.to_list()
# Out:
# ['Country',
#  'Region',
#  'Happiness Score',
#  'Standard error of ladder score',
#  'upperwhisker',
#  'lowerwhisker',
#  'Logged GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption',
#  'Ladder score in Dystopia',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Generosity',
#  'Trust (Government Corruption)',
#  'Dystopia Residual',
#  'Year']

# %% [markdown]
# ## Df2021

# %%
df2021.head()
# Out:
#        Country          Region  Happiness Score  \
# 0      Finland  Western Europe            7.842
# 1      Denmark  Western Europe            7.620
# 2  Switzerland  Western Europe            7.571
# 3      Iceland  Western Europe            7.554
# 4  Netherlands  Western Europe            7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
df2021.shape, df2021.columns.to_list()
# Out:
# ((149, 21),
#  ['Country',
#   'Region',
#   'Happiness Score',
#   'Standard error of ladder score',
#   'upperwhisker',
#   'lowerwhisker',
#   'Logged GDP per capita',
#   'Social support',
#   'Healthy life expectancy',
#   'Freedom to make life choices',
#   'Perceptions of corruption',
#   'Ladder score in Dystopia',
#   'Economy (GDP per Capita)',
#   'Family',
#   'Health (Life Expectancy)',
#   'Freedom',
#   'Generosity',
#   'Trust (Government Corruption)',
#   'Dystopia Residual',
#   'Year',
#   'Happiness Rank'])

# %%
df2021['Generosity']
# Out:
# 0      0.124
# 1      0.208
# 2      0.204
# 3      0.293
# 4      0.302
#        ...
# 144    0.103
# 145    0.027
# 146    0.227
# 147    0.157
# 148    0.122
# Name: Generosity, Length: 149, dtype: float64

# %%
df2021 = df2021.loc[:,~df2021.columns.duplicated(keep='last')]

# %%
#rename some column names
df2021 = df2021.rename(columns={'Country name':'Country','Regional indicator': 'Region','Ladder score':'Happiness Score','Explained by: Social support':'Family','Explained by: Healthy life expectancy':'Health (Life Expectancy)','Explained by: Freedom to make life choices':'Freedom','Explained by: Perceptions of corruption':'Trust (Government Corruption)','Explained by: Log GDP per capita':'Economy (GDP per Capita)','Explained by: Generosity':'Generosity','Dystopia + residual':'Dystopia Residual'})

# %%
df2021.columns.to_list()
# Out:
# ['Country',
#  'Region',
#  'Happiness Score',
#  'Standard error of ladder score',
#  'upperwhisker',
#  'lowerwhisker',
#  'Logged GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Perceptions of corruption',
#  'Ladder score in Dystopia',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Generosity',
#  'Trust (Government Corruption)',
#  'Dystopia Residual',
#  'Year',
#  'Happiness Rank']

# %%
df2021['Happiness Rank'] = [i for i in range(1, len(df2021.index)+1)]

# %%
df2021.tail()
# Out:
#          Country              Region  Happiness Score  \
# 144      Lesotho  Sub-Saharan Africa            3.512
# 145     Botswana  Sub-Saharan Africa            3.467
# 146       Rwanda  Sub-Saharan Africa            3.415
# 147     Zimbabwe  Sub-Saharan Africa            3.145
# 148  Afghanistan          South Asia            2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 144                           0.120         3.748         3.276
# 145                           0.074         3.611         3.322
# 146                           0.068         3.548         3.282
# 147                           0.058         3.259         3.030
# 148                           0.038         2.596         2.449
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 144                  7.926           0.787                   48.700
# 145                  9.782           0.784                   59.269
# ...

# %% [markdown]
# ## Merge all dfs into one

# %%
#get shared columns in all dfs
dfs = [df2015[common_cols], df2016[common_cols], df2017[common_cols], df2018[common_cols], df2019[common_cols], df2020[common_cols], df2021[common_cols]]
common_cols = list(set.intersection(*(set(df.columns) for df in dfs)))

# %%
common_cols
# Out:
# ['Happiness Rank',
#  'Region',
#  'Freedom',
#  'Happiness Score',
#  'Country',
#  'Generosity',
#  'Family',
#  'Trust (Government Corruption)',
#  'Health (Life Expectancy)',
#  'Economy (GDP per Capita)',
#  'Year']

# %%
#concate dfs on common cols
# df_merged = pd.concat([df[common_cols] for df in dfs], ignore_index=True)

# %%
df_merged = pd.DataFrame(columns=common_cols)

# %% [markdown]
# There is a problem with df2020 and df2021. Let's find out.

# %%
# df2020_copy = df2020[common_cols].copy()

# %%
# df2020_copy

# %%
# df2018

# %%
df_merged = df_merged.append(dfs)

# %%
df_merged.shape
# Out:
# (1084, 11)

# %%
df = df_merged.to_csv('World-Happiness-Analysis-2015-2021.csv')
